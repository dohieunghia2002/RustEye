# %%
# !pip install ultralytics

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !unzip -q /content/drive/MyDrive/My_Research/RUSTEYE/data.zip -d /content/

# %%
from ultralytics import YOLO


model = YOLO("yolo11l-seg.pt")

# Train the model
results = model.train(data="data.yaml", batch=8, epochs=40)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.176 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !zip -r runs.zip runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/segment/ (stored 0%)
#   adding: runs/segment/train/ (stored 0%)
#   adding: runs/segment/train/BoxR_curve.png (deflated 17%)
#   adding: runs/segment/train/train_batch5791.jpg (deflated 9%)
#   adding: runs/segment/train/labels_correlogram.jpg (deflated 30%)
#   adding: runs/segment/train/results.png (deflated 7%)
#   adding: runs/segment/train/BoxPR_curve.png (deflated 18%)
#   adding: runs/segment/train/BoxF1_curve.png (deflated 18%)
#   adding: runs/segment/train/val_batch2_labels.jpg (deflated 6%)
#   adding: runs/segment/train/results.csv (deflated 58%)
#   adding: runs/segment/train/train_batch1.jpg (deflated 2%)
#   adding: runs/segment/train/labels.jpg (deflated 28%)
#   adding: runs/segment/train/val_batch0_labels.jpg (deflated 5%)
#   adding: runs/segment/train/MaskF1_curve.png (deflated 18%)
#   adding: runs/segment/train/train_batch2.jpg (deflated 2%)
#   adding: runs/segment/train/confusion_matrix.png (deflated 34%)
# ...

# %%
# !mv /content/runs.zip /content/drive/MyDrive/My_Research/RUSTEYE/
